# %%
import torch
from torch import nn
from torch.nn import init

# %%
net = nn.Sequential(nn.Linear(4,3),nn.ReLU(),nn.Linear(3,1))
 # pytorch已进行默认初始化
print(net)
X = torch.rand(2, 4)
Y = net(X).sum()
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=3, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
print(type(net.named_parameters()))
for name, param in net.named_parameters():
    print(name, param.size())
# Out:
# <class 'generator'>
# 0.weight torch.Size([3, 4])
# 0.bias torch.Size([3])
# 2.weight torch.Size([1, 3])
# 2.bias torch.Size([1])

# %%
for name, param in net[0].named_parameters():
    print(name, param.size(), type(param))
# Out:
# weight torch.Size([3, 4]) <class 'torch.nn.parameter.Parameter'>
# bias torch.Size([3]) <class 'torch.nn.parameter.Parameter'>

# %%
class MyModel(nn.Module):
    def __init__(self,**kwargs):
        super(MyModel,self).__init__(**kwargs)
        self.weight1=nn.Parameter(torch.rand(20,20))
        self.weight2=torch.randn(20,20)
    def forward(self,x):
        pass

# %%
n=MyModel()
for name,param in n.named_parameters():
    print(name)
# Out:
# weight1

# %%
weight_0 = list(net[0].parameters())[0]
print(weight_0.data)
print(weight_0.grad) # 反向传播前梯度为None
Y.backward()
print(weight_0.grad)
# Out:
# tensor([[ 0.3489,  0.4571, -0.4128, -0.2819],
#         [ 0.3383,  0.0063,  0.1582, -0.1606],
#         [ 0.0635,  0.0935, -0.2126,  0.0067]])
# None
# tensor([[ 0.0000,  0.0000,  0.0000,  0.0000],
#         [-0.1598, -0.0191, -0.0659, -0.1535],
#         [ 0.0000,  0.0000,  0.0000,  0.0000]])

# %%
for name, param in net.named_parameters():
    if 'weight' in name:
        init.normal_(param, mean=0, std=0.01)
        print(name, param.data)
# Out:
# 0.weight tensor([[-0.0052, -0.0097, -0.0083, -0.0147],
#         [ 0.0095,  0.0046,  0.0055, -0.0020],
#         [ 0.0032, -0.0026, -0.0061,  0.0182]])
# 2.weight tensor([[-0.0009,  0.0085, -0.0005]])

# %%
for name, param in net.named_parameters():
    if 'bias' in name:
        init.constant_(param, val=0)
        print(name, param.data)
# Out:
# 0.bias tensor([0., 0., 0.])
# 2.bias tensor([0.])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def init_weight_(tensor):
    with torch.no_grad():
        tensor.uniform_(-10, 10)
        tensor *= (tensor.abs() >= 5).float()

for name, param in net.named_parameters():
    if 'weight' in name:
        init_weight_(param)
        print(name, param.data)
# Out:
# 0.weight tensor([[ 9.2801,  0.0000,  9.1337, -0.0000],
#         [ 8.1079,  0.0000, -0.0000, -0.0000],
#         [-5.1851, -5.9172, -0.0000, -6.7404]])
# 2.weight tensor([[ 6.5273, -8.9243, -0.0000]])

# %%
for name, param in net.named_parameters():
    if 'bias' in name:
        param.data += 1
        print(name, param.data)
# Out:
# 0.bias tensor([1., 1., 1.])
# 2.bias tensor([1.])

# %%
linear = nn.Linear(1, 1, bias=False)
net = nn.Sequential(linear, linear) 
print(net)
for name, param in net.named_parameters():
    init.constant_(param, val=3)
    print(name, param.data)
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=1, bias=False)
#   (1): Linear(in_features=1, out_features=1, bias=False)
# )
# 0.weight tensor([[3.]])

# %%
print(id(net[0]) == id(net[1]))
print(id(net[0].weight) == id(net[1].weight))
# Out:
# True
# True

# %%
x = torch.ones(1, 1)
y = net(x).sum()
print(y)
y.backward()
print(net[0].weight.grad) # 单次梯度是3，两次所以就是6
# Out:
# tensor(9., grad_fn=<SumBackward0>)
# tensor([[6.]])
